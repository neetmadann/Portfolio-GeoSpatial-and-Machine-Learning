# %% [markdown]
# <a href="https://colab.research.google.com/github/neetmadann/Portfolio-GeoSpatial-and-Machine-Learning/blob/main/Altair_Python_Project_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Altair Python Project

# %% [markdown]
# ### Code to grab the data

# %%
import pandas as pd
import altair as alt
import os
os. getcwd()
path = r'C:\Users\neetm\Desktop\CST 4060\CW Group 2'
os.chdir(path)
df = pd.read_csv('gapminder.csv')
df.head()
len(df)
# Out:
# 10111

# %%
df.head()
# Out:
#        Country  Year  fertility    life  population  child_mortality     gdp  \
# 0  Afghanistan  1964      7.671  33.639  10474903.0            339.7  1182.0
# 1  Afghanistan  1965      7.671  34.152  10697983.0            334.1  1182.0
# 2  Afghanistan  1966      7.671  34.662  10927724.0            328.7  1168.0
# 3  Afghanistan  1967      7.671  35.170  11163656.0            323.3  1173.0
# 4  Afghanistan  1968      7.671  35.674  11411022.0            318.1  1187.0
#
#        region
# 0  South Asia
# 1  South Asia
# 2  South Asia
# 3  South Asia
# 4  South Asia

# %% [markdown]
# ## Data Cleaning

# %%
global_df = df.groupby(['Year','region']).mean().reset_index()
pd.options.display.float_format = '{:20}'.format
global_df.head()
# Out:
#    Year                      region            fertility                 life  \
# 0  1964                     America              5.57465            60.462775
# 1  1964         East Asia & Pacific            5.7080325          56.79842875
# 2  1964       Europe & Central Asia    3.270488287352941    67.84011049254903
# 3  1964  Middle East & North Africa     6.96557142857143    52.11980952380953
# 4  1964                  South Asia               6.4805            43.877125
#
#             population      child_mortality                  gdp
# 0         11554893.425   113.95066666666666             6813.875
# 1       34708385.65625   129.10913043478263               6431.5
# 2    13703028.80392157    61.58531914893617            9760.0625
# 3    5623594.571428572   179.60526315789474   10962.157894736842
# 4         78134238.125             256.9225             1233.875

# %%
brush = alt.selection_interval()  # selection of type "interval"
chart = alt.Chart(global_df).mark_line().encode(
    alt.X('Year:Q'), #change the year take out comma
    color=alt.condition(brush, 'region:N', alt.value('lightgray'))
).properties(
    width=450,
    height=300
).add_selection(
    brush
)

chart.encode(y='gdp:Q')
# Out:
# alt.Chart(...)

# %%
brush = alt.selection_interval()  # selection of type "interval"
chart = alt.Chart(global_df).mark_line().encode(
    alt.X('Year:Q'), #change year take out comma
    color=alt.condition(brush, 'region:N', alt.value('lightgray'))
).properties(
    width=300,
    height=200
).add_selection(
    brush
)
chart.encode(y='life:Q')|chart.encode(y='child_mortality:Q')|chart.encode(y='fertility:Q').interactive()
# Out:
# alt.HConcatChart(...)

# %%
#RELAtionship
gapminder_2013 = df[df['Year']==2013]

alt.Chart(gapminder_2013).mark_circle().encode(
    alt.X(alt.repeat("column"), type='quantitative'),
    alt.Y(alt.repeat("row"), type='quantitative'),
    color='region:N'
).properties(
    width=150,
    height=150
).repeat(
    row=['fertility','life','population','child_mortality','gdp'],
    column=['fertility','life','population','child_mortality','gdp']
).interactive()
# Out:
# alt.RepeatChart(...)

# %%
df.region.unique()
region_df = global_df
region_df['gdp_per_100']=region_df['gdp']/100
region_df = pd.melt(region_df,id_vars=['Year','region'],value_vars=['gdp_per_100','fertility','child_mortality','life'])
region_df.head()
# Out:
#    Year                      region     variable                value
# 0  1964                     America  gdp_per_100             68.13875
# 1  1964         East Asia & Pacific  gdp_per_100               64.315
# 2  1964       Europe & Central Asia  gdp_per_100            97.600625
# 3  1964  Middle East & North Africa  gdp_per_100   109.62157894736842
# 4  1964                  South Asia  gdp_per_100             12.33875

# %%
sort_des = global_df.groupby(['region']).sum().reset_index()
sort_des = sort_des.sort_values(by='gdp', ascending=False)
sort_des
# Out:
#                        region   Year            fertility  \
# 3  Middle East & North Africa  99425   248.50095238095238
# 2       Europe & Central Asia  99425   110.70887364223529
# 1         East Asia & Pacific  99425         186.29178625
# 0                     America  99425          174.3030695
# 5          Sub-Saharan Africa  99425   297.80523999999997
# 4                  South Asia  99425           250.208125
#
#                   life           population      child_mortality  \
# 3   3259.7150476190477    585651497.5238096    3543.322552631579
# 2    3596.146672294423    800082771.7330316   1515.2397429078014
# 1    3305.238611780303     2733986798.09375   3096.9655124223605
# 0   3436.1125500000003         887285986.05   2637.1118888888886
# 5           2583.22129          525499232.8    7983.357034303083
# 4            2856.8855       7033908372.375            6888.3575
#
#                    gdp          gdp_per_100         gdp_per_1000  \
# 3   1375536.5789473683   13755.365789473684   1375.5365789473683
# 2    922102.2708333334    9221.022708333334    922.1022708333334
# 1    666807.8461538461    6668.078461538462    666.8078461538462
# 0         579996.09375         5799.9609375         579.99609375
# 5    157621.4255319149   1576.2142553191488    157.6214255319149
# 4             127632.5             1276.325             127.6325
#
#            pop_per_mil
# 3    585.6514975238096
# 2    800.0827717330317
# 1     2733.98679809375
# 0         887.28598605
# 5          525.4992328
# 4       7033.908372375

# %%
region_list = list(sort_des['region'].unique())
high_region = region_list[0:4]
high_region
low_region=region_list[-2:]
low_region
# Out:
# ['Sub-Saharan Africa', 'South Asia']

# %%
region_df_expand = global_df
region_df_expand['gdp_per_1000'] = global_df['gdp']/1000
region_df_expand['pop_per_mil'] = global_df['population']/1000000
region_df_expand = pd.melt(global_df,id_vars=['Year','region'],value_vars=['fertility','child_mortality','life'])
#'gdp_per_1000','pop_per_mil',

# %%
from altair.expr import datum

print('\033[1m' + 'HIGH GDP COUNTRIES' + '\033[0m')

#'Sub-Saharan Africa',
chart = alt.hconcat()
for region in high_region:
    base = alt.Chart(region_df,title=region).mark_line().encode(
    alt.X('Year:O',title='Year',axis=alt.Axis(values=list(range(1,50,10)))),
    alt.Y('value:Q',title='Socio-Economic Measures'),
    alt.Color('variable:N')
).interactive().properties(
    width=200,
    height=200
)
    chart |= base.transform_filter(datum.region == region)
chart
# Out:
# HIGH GDP COUNTRIES
# alt.HConcatChart(...)

# %%
from altair.expr import datum

print('\033[1m' + 'FERTILITY,MORTALITY,LIFE' + '\033[0m')

#'Sub-Saharan Africa',
chart = alt.hconcat()
for region in high_region:
    base = alt.Chart(region_df_expand,title=region).mark_line().encode(
    alt.X('Year:O',title='Year',axis=alt.Axis(values=list(range(1,50,10)))),
    alt.Y('value:Q',title='Socio-Economic Measures'),
    alt.Color('variable:N')
).interactive().properties(
    width=200,
    height=200
)
    chart |= base.transform_filter(datum.region == region)
chart
# Out:
# FERTILITY,MORTALITY,LIFE
# alt.HConcatChart(...)

# %%
from altair.expr import datum

print('\033[1m' + 'LOW GDP COUNTRIES' + '\033[0m')

#'Sub-Saharan Africa',
chart = alt.hconcat()
for region in low_region:
    base = alt.Chart(region_df,title=region).mark_line().encode(
    alt.X('Year:O',title='Year',axis=alt.Axis(values=list(range(1,50,10)))),
    alt.Y('value:Q',title='Socio-Economic Measures'),
    alt.Color('variable:N')
).interactive().properties(
    width=200,
    height=200
)
    chart |= base.transform_filter(datum.region == region)
chart
# Out:
# LOW GDP COUNTRIES
# alt.HConcatChart(...)

# %%
from altair.expr import datum

print('\033[1m' + 'FERTILITY,MORTALITY,LIFE' + '\033[0m')

#'Sub-Saharan Africa',
chart = alt.hconcat()
for region in low_region:
    base = alt.Chart(region_df_expand,title=region).mark_line().encode(
    alt.X('Year:O',title='Year',axis=alt.Axis(values=list(range(1,50,10)))),
    alt.Y('value:Q',title='Socio-Economic Measures'),
    alt.Color('variable:N')
).interactive().properties(
    width=200,
    height=200
)
    chart |= base.transform_filter(datum.region == region)
chart
# Out:
# FERTILITY,MORTALITY,LIFE
# alt.HConcatChart(...)
